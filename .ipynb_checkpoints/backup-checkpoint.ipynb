# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install xgboost
# !pip install keras
# !pip install matplotlib
# !pip install tensorflow
# Out:
# Requirement already satisfied: pandas in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (1.26.2)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xgboost in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.26.2)
# Requirement already satisfied: scipy in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.11.4)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: keras in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (2.15.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\alonj\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import packages and modules
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
df  = pd.read_csv("Tetuan City power consumption.csv")

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# 2                19668.43373
# 3                18899.27711
# 4                18442.40964

# %%
df.columns
# Out:
# Index(['DateTime', 'Temperature', 'Humidity', 'Wind Speed',
#        'general diffuse flows', 'diffuse flows', 'Zone 1 Power Consumption',
#        'Zone 2  Power Consumption', 'Zone 3  Power Consumption'],
#       dtype='object')

# %%
#Data Visualization
# Pairplot to visualize relationships between numerical columns
sns.pairplot(df[['Temperature', 'Humidity', 'Wind Speed', 'Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption']])
plt.show()

# %%
# Time series plot for PowerConsumption
plt.figure(figsize=(12, 6))
sns.lineplot(x='DateTime', y='Zone 1 Power Consumption', data=df, label='Zone 1')
plt.xlabel('Datetime')
plt.ylabel('Power Consumption')
plt.title('Power Consumption Over Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 7
#       5 plt.ylabel('Power Consumption')
#       6 plt.title('Power Consumption Over Time')
# ----> 7 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2167, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
# -> 2167         bbox_inches = self.figure.get_tightbbox(
#    2168             renderer, bbox_extra_artists=bbox_extra_artists)
#    2169         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2170                 pad_inches == "layout"):
#    2171             h_pad = layout_engine.get()["h_pad"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:1774, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1771     artists = bbox_extra_artists
#    1773 for a in artists:
# -> 1774     bbox = a.get_tightbbox(renderer)
#    1775     if bbox is not None:
#    1776         bb.append(bbox)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:4395, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4393 for axis in self._axis_map.values():
#    4394     if self.axison and axis.get_visible():
# -> 4395         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4396         if ba:
#    4397             bb.append(ba)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:1411, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1405 """
#    1406 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1407 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1408 when encountering third-party subclasses that do not support it.
#    1409 """
#    1410 try:
# -> 1411     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1412 except TypeError:
#    1413     return obj.get_tightbbox(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1339, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1336 self._update_label_position(renderer)
#    1338 # go back to just this axis's tick labels
# -> 1339 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1341 self._update_offset_text_position(tlb1, tlb2)
#    1342 self.offsetText.set_text(self.major.formatter.get_offset())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1315, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1315, in <listcomp>(.0)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:956, in Text.get_window_extent(self, renderer, dpi)
#     951     raise RuntimeError(
#     952         "Cannot get window extent of text w/o renderer. You likely "
#     953         "want to call 'figure.draw_without_rendering()' first.")
#     955 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 956     bbox, info, descent = self._get_layout(self._renderer)
#     957     x, y = self.get_unitless_position()
#     958     x, y = self.get_transform().transform((x, y))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:221, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     218     return width, height, descent
#     220 font = self._prepare_font(prop)
# --> 221 font.set_text(s, 0.0, flags=get_hinting_flag())
#     222 w, h = font.get_width_height()  # width and height of unrotated string
#     223 d = font.get_descent()
#
# KeyboardInterrupt:

# %%
# Time series plot for PowerConsumption
plt.figure(figsize=(12, 6))
sns.lineplot(x='DateTime', y='Zone 2  Power Consumption', data=df, label='Zone 2')
plt.xlabel('Datetime')
plt.ylabel('Power Consumption')
plt.title('Power Consumption Over Time')
plt.show()

# %%
# Time series plot for PowerConsumption
plt.figure(figsize=(12, 6))
sns.lineplot(x='DateTime', y='Zone 3  Power Consumption', data=df, label='Zone 2')
plt.xlabel('Datetime')
plt.ylabel('Power Consumption')
plt.title('Power Consumption Over Time')
plt.show()

# %%
df['DateTime']=pd.to_datetime(df.DateTime)
df.sort_values(by='DateTime', ascending=True, inplace=True)

chronological_order = df['DateTime'].is_monotonic_increasing

time_diffs = df['DateTime'].diff()
equidistant_timestamps = time_diffs.nunique() == 1

# %%
chronological_order, equidistant_timestamps
# Out:
# (True, True)

# %%
df.isna().sum()
# Out:
# DateTime                     0
# Temperature                  0
# Humidity                     0
# Wind Speed                   0
# general diffuse flows        0
# diffuse flows                0
# Zone 1 Power Consumption     0
# Zone 2  Power Consumption    0
# Zone 3  Power Consumption    0
# dtype: int64

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['minute'] = df.index.minute
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['day'] = df.index.month
    df['year'] = df.index.year
    df['season'] = df['month'] % 12 // 3 + 1
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    
    # Additional features
    df['is_weekend'] = df['dayofweek'].isin([5, 6]).astype(int)
    df['is_month_start'] = (df['dayofmonth'] == 1).astype(int)
    df['is_month_end'] = (df['dayofmonth'] == df.index.days_in_month).astype(int)
    df['is_quarter_start'] = (df['dayofmonth'] == 1) & (df['month'] % 3 == 1).astype(int)
    df['is_quarter_end'] = (df['dayofmonth'] == df.groupby(['year', 'quarter'])['dayofmonth'].transform('max'))
    
    # Additional features
    df['is_working_day'] = df['dayofweek'].isin([0, 1, 2, 3, 4]).astype(int)
    df['is_business_hours'] = df['hour'].between(9, 17).astype(int)
    df['is_peak_hour'] = df['hour'].isin([8, 12, 18]).astype(int)
    
    # Minute-level features
    df['minute_of_day'] = df['hour'] * 60 + df['minute']
    df['minute_of_week'] = (df['dayofweek'] * 24 * 60) + df['minute_of_day']
    
    return df.astype(float)

# %%
df = df.set_index('DateTime')
df = create_features(df)

# %%
# df[[ 'year', 'month', 'day','minute', 'dayofyear', 'weekofyear', 'quarter', 'season']].head()

# %%
# Calculate correlation matrix
correlation_matrix = df[['Temperature', 'Humidity', 'Wind Speed', 'Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption']].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Resample the data for more meaningful time series analysis (e.g., daily, weekly)
daily_resampled = df.resample('D').mean()

# Plot daily Power Consumption for each zone
plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_resampled[['Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption']])
plt.xlabel('Date')
plt.ylabel('Average Power Consumption')
plt.title('Average Daily Power Consumption')
plt.legend(labels=['Zone 1', 'Zone 2', 'Zone 3'])
plt.show()

# %%
_predict_test = pd.DataFrame()
for _i in np.random.uniform(0, 50000, 10):
    # Add columns to the DataFrame
    # _predict_test = df.append(dict(df.iloc[int(_i)]), ignore_index=True)
    _predict_test = pd.concat([_predict_test, pd.DataFrame([dict(df.iloc[int(_i)])])], ignore_index=True)
    df = df.drop(df.index[int(_i)])

_predict_test
# Out:
#    Temperature  Humidity  Wind Speed  general diffuse flows  diffuse flows  \
# 0        22.32     73.60       4.924                 44.030         41.200
# 1        24.42     46.05       2.449                 91.500         69.770
# 2        16.93     72.40       4.909                  0.033          0.122
# 3        16.03     82.30       0.091                  0.051          0.137
# 4        13.55     78.90       4.916                 17.570         15.510
# 5         8.24     90.40       0.082                  0.081          0.145
# 6         7.35     81.10       0.085                  0.077          0.156
# 7        10.43     82.30       0.071                  0.048          0.163
# 8        14.16     81.30       0.079                  0.044          0.137
# 9        20.43     85.00       0.069                  0.629          0.586
#
#    Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0               44166.29508                27284.21053
# 1               30182.65487                17869.02287
# 2               24085.06329                14465.65350
# 3               26934.61707                16543.56846
# 4               25209.19149                14974.39024
# 5               22289.49153                13024.92401
# 6               22947.52852                18760.35594
# 7               29208.81356                16989.66565
# 8               22457.17976                13303.86965
# 9               21743.04636                13688.98129
#
#    Zone 3  Power Consumption  hour  minute
# 0                26631.25506  20.0     0.0
# 1                16803.43207  18.0    20.0
# 2                15325.30120   2.0     0.0
# 3                11858.48024   4.0    50.0
# 4                11839.35484   7.0    20.0
# 5                14426.05025   4.0    10.0
# 6                10740.93637   1.0    20.0
# 7                17210.53266   0.0    20.0
# 8                14871.27273   3.0    20.0
# 9                10497.96923   5.0    50.0

# %%
from sklearn.preprocessing import StandardScaler

# Separate the input features (X) and target variables (y)
X = df.drop(['Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption'], axis=1)
y = df[['Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption']]

# Initialize StandardScaler for y
scaler_y = StandardScaler()

# Fit and transform  y
y_scaled = scaler_y.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_scaled, test_size=0.25, shuffle=False)

# %%
from keras import optimizers

epochs = 40
batch = 256
lr = 0.0003
adam = optimizers.Adam(lr)
# Out:
# WARNING:tensorflow:From C:\Users\alonj\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from keras.models import Sequential
from keras.layers import Dense
model_mlp = Sequential()
model_mlp.add(Dense(100, activation='relu', input_dim=X_train.shape[1]))
model_mlp.add(Dense(3))
model_mlp.compile(loss='mse', optimizer=adam)
model_mlp.summary()
# Out:
# WARNING:tensorflow:From C:\Users\alonj\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               800
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 1103 (4.31 KB)
# Trainable params: 1103 (4.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
mlp_history = model_mlp.fit(X_train.values, y_train, validation_data=(X_test.values, y_test), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# WARNING:tensorflow:From C:\Users\alonj\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1229/1229 - 2s - loss: 43.2300 - val_loss: 1.3802 - 2s/epoch - 2ms/step
# Epoch 2/40
# 1229/1229 - 1s - loss: 0.6909 - val_loss: 1.0449 - 1s/epoch - 1ms/step
# Epoch 3/40
# 1229/1229 - 1s - loss: 0.5512 - val_loss: 0.9574 - 1s/epoch - 1ms/step
# Epoch 4/40
# 1229/1229 - 2s - loss: 0.5032 - val_loss: 0.9225 - 2s/epoch - 1ms/step
# Epoch 5/40
# 1229/1229 - 1s - loss: 0.4758 - val_loss: 0.9451 - 1s/epoch - 1ms/step
# Epoch 6/40
# 1229/1229 - 2s - loss: 0.4620 - val_loss: 0.9060 - 2s/epoch - 1ms/step
# Epoch 7/40
# 1229/1229 - 2s - loss: 0.4497 - val_loss: 0.8651 - 2s/epoch - 1ms/step
# Epoch 8/40
# 1229/1229 - 1s - loss: 0.4368 - val_loss: 0.7735 - 1s/epoch - 1ms/step
# Epoch 9/40
# 1229/1229 - 1s - loss: 0.4237 - val_loss: 1.0065 - 1s/epoch - 1ms/step
# Epoch 10/40
# 1229/1229 - 1s - loss: 0.4053 - val_loss: 0.7482 - 1s/epoch - 1ms/step
# Epoch 11/40
# 1229/1229 - 1s - loss: 0.3760 - val_loss: 0.8179 - 1s/epoch - 1ms/step
# Epoch 12/40
# 1229/1229 - 1s - loss: 0.3708 - val_loss: 0.7603 - 1s/epoch - 1ms/step
# Epoch 13/40
# 1229/1229 - 1s - loss: 0.3577 - val_loss: 0.7176 - 1s/epoch - 1ms/step
# Epoch 14/40
# 1229/1229 - 1s - loss: 0.3551 - val_loss: 0.7375 - 1s/epoch - 1ms/step
# Epoch 15/40
# 1229/1229 - 1s - loss: 0.3521 - val_loss: 0.7071 - 1s/epoch - 1ms/step
# Epoch 16/40
# 1229/1229 - 1s - loss: 0.3500 - val_loss: 0.6756 - 1s/epoch - 1ms/step
# Epoch 17/40
# 1229/1229 - 1s - loss: 0.3477 - val_loss: 0.7493 - 1s/epoch - 1ms/step
# Epoch 18/40
# 1229/1229 - 1s - loss: 0.3416 - val_loss: 0.8234 - 1s/epoch - 1ms/step
# Epoch 19/40
# 1229/1229 - 1s - loss: 0.3342 - val_loss: 0.6940 - 1s/epoch - 1ms/step
# Epoch 20/40
# 1229/1229 - 1s - loss: 0.3392 - val_loss: 0.7156 - 1s/epoch - 1ms/step
# Epoch 21/40
# 1229/1229 - 1s - loss: 0.3273 - val_loss: 0.6382 - 1s/epoch - 1ms/step
# Epoch 22/40
# 1229/1229 - 1s - loss: 0.3337 - val_loss: 0.6667 - 1s/epoch - 1ms/step
# Epoch 23/40
# 1229/1229 - 1s - loss: 0.3265 - val_loss: 0.7875 - 1s/epoch - 1ms/step
# Epoch 24/40
# 1229/1229 - 1s - loss: 0.3227 - val_loss: 0.7191 - 1s/epoch - 1ms/step
# Epoch 25/40
# 1229/1229 - 1s - loss: 0.3148 - val_loss: 0.6369 - 1s/epoch - 1ms/step
# Epoch 26/40
# 1229/1229 - 1s - loss: 0.3223 - val_loss: 0.6629 - 1s/epoch - 1ms/step
# Epoch 27/40
# 1229/1229 - 2s - loss: 0.3220 - val_loss: 0.6841 - 2s/epoch - 1ms/step
# Epoch 28/40
# 1229/1229 - 2s - loss: 0.3184 - val_loss: 0.7054 - 2s/epoch - 1ms/step
# Epoch 29/40
# 1229/1229 - 2s - loss: 0.3174 - val_loss: 0.6719 - 2s/epoch - 1ms/step
# Epoch 30/40
# 1229/1229 - 2s - loss: 0.3160 - val_loss: 0.8313 - 2s/epoch - 1ms/step
# Epoch 31/40
# 1229/1229 - 1s - loss: 0.3167 - val_loss: 0.7909 - 1s/epoch - 1ms/step
# Epoch 32/40
# 1229/1229 - 1s - loss: 0.3115 - val_loss: 0.7067 - 1s/epoch - 1ms/step
# Epoch 33/40
# 1229/1229 - 1s - loss: 0.3193 - val_loss: 0.7152 - 1s/epoch - 1ms/step
# Epoch 34/40
# 1229/1229 - 1s - loss: 0.3104 - val_loss: 0.6468 - 1s/epoch - 1ms/step
# Epoch 35/40
# 1229/1229 - 1s - loss: 0.3156 - val_loss: 0.6339 - 1s/epoch - 1ms/step
# Epoch 36/40
# 1229/1229 - 1s - loss: 0.3126 - val_loss: 0.7339 - 1s/epoch - 1ms/step
# Epoch 37/40
# 1229/1229 - 1s - loss: 0.3067 - val_loss: 0.6280 - 1s/epoch - 1ms/step
# Epoch 38/40
# 1229/1229 - 1s - loss: 0.3112 - val_loss: 0.7879 - 1s/epoch - 1ms/step
# Epoch 39/40
# 1229/1229 - 1s - loss: 0.3193 - val_loss: 0.8516 - 1s/epoch - 1ms/step
# Epoch 40/40
# 1229/1229 - 2s - loss: 0.3004 - val_loss: 0.7398 - 2s/epoch - 1ms/step

# %%
train_predict = model_mlp.predict(X_train)
test_predict = model_mlp.predict(X_test)


# Calculate MSE and MAE as you already did
mse = mean_squared_error(y_test, test_predict)
mae = mean_absolute_error(y_test, test_predict)

# Print the results
print("Mean squared error on test set: {:.4f}".format(mse))
print("Mean absolute error on test set: {:.4f}".format(mae))
# Out:
# 1229/1229 [==============================] - 1s 886us/step
# 410/410 [==============================] - 0s 833us/step
# Mean squared error on test set: 0.7398
# Mean absolute error on test set: 0.7120

# %%
X_train_series = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_series = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))
print('Train set shape', X_train_series.shape)
print('Validation set shape', X_test_series.shape)
# Out:
# Train set shape (39304, 7, 1)
# Validation set shape (13102, 7, 1)

# %%
# from keras.layers import convolutional # import Conv1D, MaxPooling1D

from keras.layers import Conv1D, MaxPooling1D
from keras.layers import Dense, Flatten
from tensorflow.keras.optimizers.legacy import SGD
from tensorflow.keras.optimizers.legacy import Adam

model_cnn = Sequential()
model_cnn.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(X_train_series.shape[1], X_train_series.shape[2])))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())
model_cnn.add(Dense(50, activation='relu'))
model_cnn.add(Dense(3))
model_cnn.compile(loss='mse', optimizer=Adam(lr))
model_cnn.summary()
# Out:
# WARNING:tensorflow:From C:\Users\alonj\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6, 64)             192
#
#  max_pooling1d (MaxPooling1  (None, 3, 64)             0
#  D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense_2 (Dense)             (None, 50)                9650
#
#  dense_3 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 9995 (39.04 KB)
# Trainable params: 9995 (39.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn_history = model_cnn.fit(X_train_series, y_train, validation_data=(X_test_series, y_test), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 1229/1229 - 3s - loss: 5.1578 - val_loss: 0.9114 - 3s/epoch - 2ms/step
# Epoch 2/40
# 1229/1229 - 2s - loss: 0.5321 - val_loss: 0.8960 - 2s/epoch - 2ms/step
# Epoch 3/40
# 1229/1229 - 2s - loss: 0.4905 - val_loss: 0.8128 - 2s/epoch - 2ms/step
# Epoch 4/40
# 1229/1229 - 2s - loss: 0.4634 - val_loss: 0.8661 - 2s/epoch - 2ms/step
# Epoch 5/40
# 1229/1229 - 2s - loss: 0.4481 - val_loss: 0.7547 - 2s/epoch - 2ms/step
# Epoch 6/40
# 1229/1229 - 2s - loss: 0.4211 - val_loss: 0.7730 - 2s/epoch - 2ms/step
# Epoch 7/40
# 1229/1229 - 2s - loss: 0.4219 - val_loss: 0.7076 - 2s/epoch - 2ms/step
# Epoch 8/40
# 1229/1229 - 2s - loss: 0.4110 - val_loss: 0.7115 - 2s/epoch - 2ms/step
# Epoch 9/40
# 1229/1229 - 2s - loss: 0.3927 - val_loss: 0.8012 - 2s/epoch - 2ms/step
# Epoch 10/40
# 1229/1229 - 2s - loss: 0.3968 - val_loss: 0.8250 - 2s/epoch - 2ms/step
# Epoch 11/40
# 1229/1229 - 2s - loss: 0.3827 - val_loss: 0.8075 - 2s/epoch - 2ms/step
# Epoch 12/40
# 1229/1229 - 2s - loss: 0.3694 - val_loss: 0.8026 - 2s/epoch - 2ms/step
# Epoch 13/40
# 1229/1229 - 2s - loss: 0.3592 - val_loss: 0.8987 - 2s/epoch - 2ms/step
# Epoch 14/40
# 1229/1229 - 2s - loss: 0.3608 - val_loss: 0.7022 - 2s/epoch - 2ms/step
# Epoch 15/40
# 1229/1229 - 2s - loss: 0.3507 - val_loss: 0.6127 - 2s/epoch - 2ms/step
# Epoch 16/40
# 1229/1229 - 2s - loss: 0.3487 - val_loss: 0.8050 - 2s/epoch - 2ms/step
# Epoch 17/40
# 1229/1229 - 2s - loss: 0.3383 - val_loss: 0.6919 - 2s/epoch - 2ms/step
# Epoch 18/40
# 1229/1229 - 2s - loss: 0.3312 - val_loss: 0.8686 - 2s/epoch - 2ms/step
# Epoch 19/40
# 1229/1229 - 2s - loss: 0.3290 - val_loss: 0.6394 - 2s/epoch - 2ms/step
# Epoch 20/40
# 1229/1229 - 2s - loss: 0.3316 - val_loss: 0.7548 - 2s/epoch - 2ms/step
# Epoch 21/40
# 1229/1229 - 2s - loss: 0.3181 - val_loss: 0.6810 - 2s/epoch - 2ms/step
# Epoch 22/40
# 1229/1229 - 2s - loss: 0.3103 - val_loss: 0.8329 - 2s/epoch - 2ms/step
# Epoch 23/40
# 1229/1229 - 2s - loss: 0.3111 - val_loss: 0.7351 - 2s/epoch - 2ms/step
# Epoch 24/40
# 1229/1229 - 2s - loss: 0.2992 - val_loss: 0.7220 - 2s/epoch - 2ms/step
# Epoch 25/40
# 1229/1229 - 2s - loss: 0.3015 - val_loss: 0.8827 - 2s/epoch - 2ms/step
# Epoch 26/40
# 1229/1229 - 2s - loss: 0.2944 - val_loss: 0.6649 - 2s/epoch - 2ms/step
# Epoch 27/40
# 1229/1229 - 2s - loss: 0.2931 - val_loss: 0.6713 - 2s/epoch - 2ms/step
# Epoch 28/40
# 1229/1229 - 2s - loss: 0.2850 - val_loss: 0.6975 - 2s/epoch - 2ms/step
# Epoch 29/40
# 1229/1229 - 2s - loss: 0.2889 - val_loss: 0.6712 - 2s/epoch - 2ms/step
# Epoch 30/40
# 1229/1229 - 2s - loss: 0.2747 - val_loss: 0.7401 - 2s/epoch - 2ms/step
# Epoch 31/40
# 1229/1229 - 2s - loss: 0.2681 - val_loss: 0.5556 - 2s/epoch - 2ms/step
# Epoch 32/40
# 1229/1229 - 2s - loss: 0.2660 - val_loss: 0.6483 - 2s/epoch - 2ms/step
# Epoch 33/40
# 1229/1229 - 2s - loss: 0.2541 - val_loss: 0.6695 - 2s/epoch - 2ms/step
# Epoch 34/40
# 1229/1229 - 2s - loss: 0.2548 - val_loss: 0.6079 - 2s/epoch - 2ms/step
# Epoch 35/40
# 1229/1229 - 2s - loss: 0.2494 - val_loss: 0.7346 - 2s/epoch - 2ms/step
# Epoch 36/40
# 1229/1229 - 2s - loss: 0.2460 - val_loss: 0.5901 - 2s/epoch - 2ms/step
# Epoch 37/40
# 1229/1229 - 2s - loss: 0.2397 - val_loss: 0.6218 - 2s/epoch - 2ms/step
# Epoch 38/40
# 1229/1229 - 2s - loss: 0.2407 - val_loss: 0.7407 - 2s/epoch - 2ms/step
# Epoch 39/40
# 1229/1229 - 2s - loss: 0.2358 - val_loss: 0.5860 - 2s/epoch - 2ms/step
# Epoch 40/40
# 1229/1229 - 2s - loss: 0.2352 - val_loss: 0.7234 - 2s/epoch - 2ms/step

# %%
y_test, test_predict
# Out:
# (array([[-0.08279975, -0.58798643, -0.4434961 ],
#         [-0.1641128 , -0.65978502, -0.49901428],
#         [-0.30729448, -0.74881527, -0.53073895],
#         ...,
#         [-0.38640111,  0.81409953, -0.60846587],
#         [-0.47513586,  0.70153944, -0.65284264],
#         [-0.56045773,  0.57906839, -0.67807649]]),
#  array([[-0.14406148, -0.4592991 ,  0.30072483],
#         [-0.24817201, -0.5438282 ,  0.27754924],
#         [-0.1262337 , -0.46770626,  0.3398101 ],
#         ...,
#         [-0.07249051, -0.2567761 ,  0.37421325],
#         [-0.36261898, -0.43466437,  0.20947734],
#         [-0.23126072, -0.2886686 ,  0.22888216]], dtype=float32))

# %%
train_predict = model_cnn.predict(X_train)
test_predict = model_cnn.predict(X_test)


# Calculate MSE and MAE as you already did
mse = mean_squared_error(y_test, test_predict)
mae = mean_absolute_error(y_test, test_predict)

# Print the results
print("Mean squared error on test set: {:.4f}".format(mse))
print("Mean absolute error on test set: {:.4f}".format(mae))
# Out:
# 1229/1229 [==============================] - 1s 954us/step
# 410/410 [==============================] - 0s 991us/step
# Mean squared error on test set: 0.7234
# Mean absolute error on test set: 0.7165

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10, 8))

ax1.plot(mlp_history.history['loss'], label='MLP Train loss')
ax1.plot(mlp_history.history['val_loss'], label='MLP Validation loss')
ax1.legend(loc='best')
ax1.set_title('MLP Loss')
ax1.set_ylabel('MSE')

ax2.plot(cnn_history.history['loss'], label='CNN Train loss')
ax2.plot(cnn_history.history['val_loss'], label='CNN Validation loss')
ax2.legend(loc='best')
ax2.set_title('CNN Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')

plt.tight_layout()
plt.show()

# %%
# Out:
#            DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  10/18/2017 13:20        19.46     89.20       0.080                164.000
# 1    7/4/2017 20:10        24.97     79.20       4.920                 19.410
# 2    8/4/2017 18:30        27.18     72.80       4.904                168.700
# 3   9/24/2017 14:50        24.72     60.95       4.919                630.300
# 4   5/26/2017 11:00        20.43     75.30       4.923                801.000
# 5     5/1/2017 2:10        17.77     67.06       0.079                  0.077
# 6   12/9/2017 11:20        10.62     73.30       0.083                382.300
# 7   12/7/2017 20:10        11.90     70.00       0.079                  0.051
# 8   2/22/2017 23:00        12.57     66.76       0.085                  0.051
# 9   2/24/2017 12:00        14.07     50.43       0.086                645.400
#
#    diffuse flows
# 0        137.400
# 1         16.160
# 2        131.800
# 3         95.400
# 4         70.400
# 5          0.115
# 6         59.410
# 7          0.137
# 8          0.145
# 9        691.800

# %%
_predict_x = _predict_test.drop(['Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption'], axis=1)
_predict_y = _predict_test[['Zone 1 Power Consumption', 'Zone 2  Power Consumption', 'Zone 3  Power Consumption']]
test = model_cnn.predict(_predict_x)
test
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[ 1.4241436 ,  0.7202259 ,  1.133834  ],
#        [ 0.7516493 ,  0.2802403 ,  0.65562236],
#        [-0.65403414, -0.8871724 , -0.08224466],
#        [-1.1838505 , -1.4821682 , -0.44307   ],
#        [-1.0543787 , -1.2201922 , -0.96859133],
#        [-1.3981705 , -1.3802915 , -0.6070415 ],
#        [-1.0716186 , -1.1556292 , -0.18866363],
#        [-0.6940093 , -0.9298152 ,  0.0796923 ],
#        [-1.1459525 , -1.3260009 , -0.3346795 ],
#        [-1.0150373 , -1.2951044 , -0.5308393 ]], dtype=float32)

# %%
test
